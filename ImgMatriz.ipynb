# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
plt.style.use('classic')

imagen = Image.open(".\\Imagenes\\zebra.jpg")

plt.imshow(imagen)

# %%
imagen_gr=imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=2592x2592 at 0x129E6577510>

# %%
imagen_mat=np.array(list(imagen_gr.getdata(band=0)),float)
print(imagen_mat)
# Out:
# [222. 222. 222. ... 157. 157. 157.]

# %%
imagen_mat.shape = (imagen_gr.size[1],imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[222. 222. 222. ... 241. 241. 241.]
#  [222. 222. 222. ... 241. 241. 241.]
#  [222. 222. 222. ... 241. 241. 241.]
#  ...
#  [ 75.  66.  53. ... 158. 158. 158.]
#  [ 69.  68.  71. ... 158. 158. 158.]
#  [ 47.  56.  71. ... 157. 157. 157.]]

# %%
print(imagen_mat.shape)
# Out:
# (2592, 2592)

# %%
plt.imshow(imagen_mat)
plt.show()

# %%
imagen_mat_2 = imagen_mat / 10
print(imagen_mat)
# Out:
# [[222. 222. 222. ... 241. 241. 241.]
#  [222. 222. 222. ... 241. 241. 241.]
#  [222. 222. 222. ... 241. 241. 241.]
#  ...
#  [ 75.  66.  53. ... 158. 158. 158.]
#  [ 69.  68.  71. ... 158. 158. 158.]
#  [ 47.  56.  71. ... 157. 157. 157.]]

# %%
#plt.imshow(imagen_mat_2,  cmap='gray', vmin=0, vmax=255)
plt.imshow(imagen_mat_2)
plt.show()
